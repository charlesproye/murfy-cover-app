# %% [markdown]
# ## Studying data for a specitif vehicle

# %%
from transform.processed_tss.ProcessedTimeSeries import TeslaProcessedTimeSeries
import pandas as pd
import plotly.express as px

# %%
tss = TeslaProcessedTimeSeries(make="tesla", force_update=False)

# %%
px.scatter(tss.query("vin == 'LRW3E7FA4MC314534'"), x="date", y="soc", color="trimmed_in_charge_idx")
