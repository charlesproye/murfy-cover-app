# %%
import plotly.express as px

from core.pandas_utils import *
from transform.processed_tss.main import get_processed_tss

# %%
tss = get_processed_tss("opel")
sanity_check(tss)

# %%
most_common_vins = tss["vin"].value_counts(sort=True).index[-5:]

tss_to_plot = tss.loc[tss["vin"].isin(most_common_vins)]
most_common_vins

# %%
px.scatter(
    tss_to_plot,
    x="date",
    y="odometer",
    color="vin",
)
