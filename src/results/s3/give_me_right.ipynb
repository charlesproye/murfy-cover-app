# %%
import plotly.express as px

from core.s3_utils import S3_Bucket

bucket = S3_Bucket()

# %%
durations = bucket.read_parquet_df("fleet_info/durations.parquet")

# %%
durations

# %%
durations["duration"].describe()

# %%
px.histogram(durations, x="duration")
