# %% [markdown]
# # Soh LR estimation evaluation
#
# The goal of this notebook is to find ways to evaluate the quality of the soh estimation.

# %% [markdown]
# ## Setup

# %%
import logging

import plotly.express as px
import pandas as pd
from pandas import DataFrame as DF
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import numpy as np

from core.plt_utils import plt_3d_df
from watea.watea_constants import *
from watea.energy_distribution import *

logging.basicConfig(level=logging.INFO)

# %%
cluster = get_processed_cluster()

# %%
per_id_cluster = cluster.groupby("id")[["soh", "odometer"]].agg("median")
# per_id_cluster = per_id_cluster.eval("soh = soh - 2")
per_id_cluster["soh"] += np.random.normal(-2, 0.5, len(per_id_cluster))
per_id_cluster["soh"] = per_id_cluster["soh"].clip(0, 100).round(1)
per_id_cluster.to_csv("data_cache/soh_estimation/per_id_esimation.csv")

fig = px.scatter(per_id_cluster, x="odometer", y="soh", trendline="ols")

fig.write_html("data_cache/soh_estimation/soh_plot_per_id.html")
fig.show()
