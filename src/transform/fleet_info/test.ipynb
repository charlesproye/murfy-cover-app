# %%
from transform.fleet_info.ayvens_fleet_info import get_fleet_info

# %%
fleet_info = get_fleet_info()

# %%
VINS = ['WBY8P210607F46593', 'WBY8P210707F59711', 'WBY8P610507F41618']

# %%
for vin in VINS: print(vin in fleet_info["vin"])
